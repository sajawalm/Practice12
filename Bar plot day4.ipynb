# %%
# import libraries
import seaborn as sns
import matplotlib.pyplot as plt

# set theme
sns.set_theme(style = "ticks", color_codes="True")# load dataset

# change figure
plt.figure(figsize=(8,6))

phool = sns.load_dataset("iris")# Iris means phool
phool

# %%
import seaborn as sns
import matplotlib.pyplot as plt
# sns.set_theme(style = "ticks", color_codes="True")

phool = sns.load_dataset("iris")# Iris means phool
sns.barplot(x ="species", y="sepal_width", data =phool) 
plt.title("phoolon ka title")
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
# sns.set_theme(style = "ticks", color_codes="True")


phool = sns.load_dataset("iris")# Iris means phool
sns.barplot(x ="species", y="petal_length", data =phool) 
plt.title("phoolon ka title")
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.set_theme(style = "ticks", color_codes="True")


kashti = sns.load_dataset("titanic")
sns.barplot(x ="sex", y="alone", hue="who", data =kashti) 
plt.title("kashti")
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.set_theme(style = "ticks", color_codes="True")


kashti = sns.load_dataset("titanic")
sns.barplot(x ="sex", y="alone", hue="who", data =kashti, order=["female","male"])# we can also reset the order 
plt.title("kashti")
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.set_theme(style = "ticks", color_codes="True")


kashti = sns.load_dataset("titanic")
sns.barplot(x ="sex", y="alone", hue="who", data =kashti, order=["female", "male"], 
            color= "grey") # use different colors from color pallets
plt.title("kashti")
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.set_theme(style = "ticks", color_codes="True")


kashti = sns.load_dataset("titanic")
sns.barplot(x ="sex", y="alone", hue="who", data =kashti, order=["female", "male"] ,color= "red",
            ci = None) # we can remove confidance interval
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.set_theme(style = "ticks", color_codes="True")


kashti = sns.load_dataset("titanic")
sns.barplot(x ="sex", y="alone", hue="who", data =kashti, order=["female", "male"] ,color= "red", ci = None,
            palette="pastel") # we can change the palette
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
from numpy import median
sns.set_theme(style = "ticks", color_codes="True")


kashti = sns.load_dataset("titanic")
sns.barplot(x ="class", y="fare", hue="sex", data =kashti, estimator=median, ci = None)
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
from numpy import median
sns.set_theme(style = "ticks", color_codes="True")


kashti = sns.load_dataset("titanic")
sns.barplot(x ="class", y="fare", hue="sex", data =kashti, estimator=median, ci = None, saturation =1 )# saturation
plt.show()

# %%
# horizantal plot


import seaborn as sns
import matplotlib.pyplot as plt
from numpy import median
sns.set_theme(style = "ticks", color_codes="True")


kashti = sns.load_dataset("titanic")
sns.barplot(x ="fare", y="class", hue="sex", data =kashti, estimator=median,saturation =1 )# saturation
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
from numpy import median
sns.set_theme(style = "ticks", color_codes="True")


kashti = sns.load_dataset("titanic")
sns.barplot(x ="class", y="fare", hue="sex", data =kashti,
           linewidth = 2.5, facecolor = (1,1,1,0),
           errcolor = ".2", edgecolor = ".2") # 0 for black and 1 for white
plt.show()
